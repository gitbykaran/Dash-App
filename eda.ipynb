# %%
import pandas as pd
import plotly.express as px
import numpy as np
import matplotlib.pyplot as ply
import seaborn as sns
# %matplotlib inline

# %%
df1 = pd.read_csv('C://Users//ASD//Desktop//Dash-App-Dev//Dash-App//electroral_bonds_buyer_data.csv')
df1.head()
# Out:
#    Unnamed: 0 Date of Purchase       Purchaser Name  Denomination
# 0           0      12/Apr/2019  A B C INDIA LIMITED        100000
# 1           1      12/Apr/2019  A B C INDIA LIMITED        100000
# 2           2      12/Apr/2019  A B C INDIA LIMITED       1000000
# 3           3      12/Apr/2019  A B C INDIA LIMITED       1000000
# 4           4      12/Apr/2019  A B C INDIA LIMITED        100000

# %%
df2 = pd.read_csv('C://Users//ASD//Desktop//Dash-App-Dev//Dash-App//electroral_bonds_receiver_data.csv')
df2.head()
# Out:
#    Unnamed: 0 Date of\nEncashment               Name of the Political Party  \
# 0           0         12/Apr/2019  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 1           1         12/Apr/2019  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 2           2         12/Apr/2019  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 3           3         12/Apr/2019  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 4           4         12/Apr/2019  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
#
#    Denomination
# 0       1000000
# 1       1000000
# 2      10000000
# 3       1000000
# 4       1000000

# %%
df = pd.merge(df1,df2,on='Unnamed: 0')
df.head()
# Out:
#    Unnamed: 0 Date of Purchase       Purchaser Name  Denomination_x  \
# 0           0      12/Apr/2019  A B C INDIA LIMITED          100000
# 1           1      12/Apr/2019  A B C INDIA LIMITED          100000
# 2           2      12/Apr/2019  A B C INDIA LIMITED         1000000
# 3           3      12/Apr/2019  A B C INDIA LIMITED         1000000
# 4           4      12/Apr/2019  A B C INDIA LIMITED          100000
#
#   Date of\nEncashment               Name of the Political Party  \
# 0         12/Apr/2019  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 1         12/Apr/2019  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 2         12/Apr/2019  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 3         12/Apr/2019  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 4         12/Apr/2019  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
#
#    Denomination_y
# 0         1000000
# 1         1000000
# 2        10000000
# 3         1000000
# 4         1000000

# %%
df=df.drop(['Unnamed: 0'],axis=1)

# %%
df.head()
# Out:
#   Date of Purchase       Purchaser Name  Denomination_x Date of\nEncashment  \
# 0      12/Apr/2019  A B C INDIA LIMITED          100000         12/Apr/2019
# 1      12/Apr/2019  A B C INDIA LIMITED          100000         12/Apr/2019
# 2      12/Apr/2019  A B C INDIA LIMITED         1000000         12/Apr/2019
# 3      12/Apr/2019  A B C INDIA LIMITED         1000000         12/Apr/2019
# 4      12/Apr/2019  A B C INDIA LIMITED          100000         12/Apr/2019
#
#                 Name of the Political Party  Denomination_y
# 0  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM         1000000
# 1  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM         1000000
# 2  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM        10000000
# 3  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM         1000000
# 4  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM         1000000

# %%
df.columns
# Out:
# Index(['Date of Purchase', 'Purchaser Name', 'Denomination_x',
#        'Date of\nEncashment', 'Name of the Political Party', 'Denomination_y'],
#       dtype='object')

# %%
df.Denomination_x.mean()
# Out:
# 6441372.052355466

# %%
df.Denomination_y.mean()
# Out:
# 6135874.251497006

# %%
df = df.drop(['Denomination_y'],axis=1)

# %%
df.columns
# Out:
# Index(['purchase_date', 'Purchaser Name', 'Denomination_x',
#        'Date of\nEncashment', 'Name of the Political Party'],
#       dtype='object')

# %%
df.rename(columns={'Date of Purchase':'purchase_date','Purchaser Name':'purchaser','Denomination_x':'amount(Rs)','Date of\nEncashment':'transaction_date','Name of the Political Party':'political_party'},inplace=True)

# %%
df
# Out:
#       purchase_date                       purchaser  amount(Rs)  \
# 0       12/Apr/2019             A B C INDIA LIMITED      100000
# 1       12/Apr/2019             A B C INDIA LIMITED      100000
# 2       12/Apr/2019             A B C INDIA LIMITED     1000000
# 3       12/Apr/2019             A B C INDIA LIMITED     1000000
# 4       12/Apr/2019             A B C INDIA LIMITED      100000
# ...             ...                             ...         ...
# 18866   11/Jan/2024  WESTWELL GASES PRIVATE LIMITED    10000000
# 18867   11/Jan/2024  WESTWELL GASES PRIVATE LIMITED    10000000
# 18868   11/Jan/2024  WESTWELL GASES PRIVATE LIMITED    10000000
# 18869   11/Jan/2024  WESTWELL GASES PRIVATE LIMITED    10000000
# 18870   11/Jan/2024  WESTWELL GASES PRIVATE LIMITED    10000000
#
#       transaction_date                           political_party
# 0          12/Apr/2019  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 1          12/Apr/2019  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# ...

# %%
df.political_party.unique()
# Out:
# array(['ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM',
#        'BHARAT RASHTRA SAMITHI', 'BHARTIYA JANTA PARTY',
#        'PRESIDENT, ALL INDIA CONGRESS COMMITTEE',
#        'SHIVSENA (POLITICAL PARTY)', 'TELUGU DESAM PARTY',
#        'YSR CONGRESS PARTY (YUVAJANA SRAMIKA R',
#        'DMK PARTY IN PARLIAMENT', 'JANATA DAL ( SECULAR )',
#        'NATIONALIST CONGRESS PARTY PARLIAMENT OF',
#        'ALL INDIA TRINAMOOL CONGRESS', 'BIHAR PRADESH JANTA DAL(UNITED)',
#        'RASTRIYA JANTA DAL', 'AAM AADMI PARTY',
#        'ADYAKSHA SAMAJVADI PARTY', 'SHIROMANI AKALI DAL',
#        'JHARKHAND MUKTI MORCHA', 'JAMMU AND KASHMIR NATIONAL CONFERENCE',
#        'BIJU JANATA DAL', 'SHIVSENA',
#        'NATIONALIST CONGRESS PARTY MAHARASHTRA PRADESH',
#        'GOA FORWARD PARTY', 'MAHARASHTRAWADI GOMNTAK PARTY',
#        'SIKKIM KRANTIKARI MORCHA', 'JANASENA PARTY',
#        'RASHTRIYA JANTA DAL', 'SIKKIM DEMOCRATIC FRONT'], dtype=object)

# %%
df.sort_values('amount(Rs)',ascending=False)
# Out:
#       purchase_date                            purchaser  amount(Rs)  \
# 9435    06/Jul/2022  FUTURE GAMING AND HOTEL SERVICES PR    10000000
# 10946   14/Nov/2022                WELSPUN INDIA LIMITED    10000000
# 10934   14/Nov/2022                      VEDANTA LIMITED    10000000
# 10935   14/Nov/2022                      VEDANTA LIMITED    10000000
# 10936   14/Nov/2022                      VEDANTA LIMITED    10000000
# ...             ...                                  ...         ...
# 11168   15/Nov/2022                SHINE COTSPIN PVT LTD        1000
# 9311    04/Jul/2022                       RITESH AGARWAL        1000
# 11166   15/Nov/2022                SHINE COTSPIN PVT LTD        1000
# 11165   15/Nov/2022                SHINE COTSPIN PVT LTD        1000
# 15991   11/Oct/2023                      HARIJAN HIRIBAI        1000
#
#       transaction_date               political_party
# 9435       15/Jan/2022  ALL INDIA TRINAMOOL CONGRESS
# ...

# %%
modi=df.query("political_party == 'BHARTIYA JANTA PARTY'").sort_values('amount(Rs)',ascending=False)
modi['amount(Rs)'].sum()
# Out:
# 51757005000

# %%
px.scatter(df,x='purchase_date',y='amount(Rs)',color=df.political_party)

# %%
px.pie(modi,values=df,names='purchaser')
